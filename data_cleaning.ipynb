# %%
import pandas as pd

# %%
df = pd.read_csv('./output.csv')

# %%
df
# Out:
#     location_indicator SUBJECT MEASURE FREQUENCY    TIME  TIME.1     Value  \
# 0      AUS_CPIFORECAST     TOT  AGRWTH         A  2015.0  2015.0  1.508367
# 1      AUS_CPIFORECAST     TOT  AGRWTH         A  2016.0  2016.0  1.253773
# 2      AUS_CPIFORECAST     TOT     NaN         A  2017.0  2017.0  1.972025
# 3      AUS_CPIFORECAST     TOT  AGRWTH         A  2018.0  2018.0  1.933888
# 4      AUS_CPIFORECAST     TOT  AGRWTH         A  2019.0  2019.0  1.551138
# ..                 ...     ...     ...       ...     ...     ...       ...
# 324   EA17_CPIFORECAST     TOT  AGRWTH         A  2017.0  2017.0  1.528207
# 325   EA17_CPIFORECAST     TOT  AGRWTH         A  2018.0  2018.0  1.761302
# 326   EA17_CPIFORECAST     TOT  AGRWTH         A  2019.0  2019.0  1.168102
# 327   EA17_CPIFORECAST     TOT  AGRWTH         A  2020.0  2020.0  1.118827
# 328   EA17_CPIFORECAST     TOT  AGRWTH         A  2021.0  2021.0  1.378801
#
#      Flag Codes
# 0           NaN
# 1           NaN
# ...

# %%
df.to_csv("./DP_LIVE_17032020113916392.csv")    #保存在当前文件夹
