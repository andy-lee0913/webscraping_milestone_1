# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('clean_cpi.csv')
#df.iloc[0:58]

# %%
sns.factorplot(data=df.iloc[0:58], x="TIME", y="Value", col="location")

# %%
df.groupby('location').describe()
# Out:
#           TIME                                                           \
#          count         mean       std     min      25%     50%      75%
# location
# ARG        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# AUS        5.0  2017.800000  2.387467  2015.0  2016.00  2018.0  2019.00
# AUT        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# BEL        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# BRA        6.0  2018.166667  2.316607  2015.0  2016.50  2018.5  2019.75
# CAN        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# CHE        6.0  2018.166667  2.316607  2015.0  2016.50  2018.5  2019.75
# CHL        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# CHN        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# COL        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# CRI        7.0  2018.000000  2.160247  2015.0  2016.50  2018.0  2019.50
# ...
